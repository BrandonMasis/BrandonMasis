# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandonMasis/BrandonMasis/blob/main/WhisperX_Youtube_SRT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install whisper-ctranslate2

# %%
from __future__ import unicode_literals
import yt_dlp
import ffmpeg
import sys

ydl_opts = {
    'format': 'bestaudio/best',
#    'outtmpl': 'output.%(ext)s',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
    }],
    "outtmpl": 'audio',  # this is where you can edit how you'd like the filenames to be formatted
}
def download_from_url(url):
    ydl.download([url])
    # stream = ffmpeg.input('output.m4a')
    # stream = ffmpeg.output(stream, 'output.wav')


with yt_dlp.YoutubeDL(ydl_opts) as ydl:
      url = "https://youtu.be/hfvtKJfoSZA?si=qEXeUaI0RbCrWA3s" #@param {type:"string"}
      download_from_url(url)
# Out:
# [youtube] Extracting URL: https://youtu.be/hfvtKJfoSZA?si=qEXeUaI0RbCrWA3s
# [youtube] hfvtKJfoSZA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] hfvtKJfoSZA: Downloading android vr player API JSON
# [info] hfvtKJfoSZA: Downloading 1 format(s): 251
# [download] Destination: audio
# [download] 100% of   27.36MiB in 00:00:06 at 3.95MiB/s
# [ExtractAudio] Destination: audio.mp3
# Deleting original file audio (pass -k to keep)

# %%
# %%capture

# !whisper-ctranslate2 audio.mp3 --model medium --output_format srt
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language 'German' with probability 0.988281
# [00:00.000 --> 00:08.400]  Hello everyone und herzlich willkommen zu einem neuen YouTube-Video von mir, nämlich einem langersehnten Makeup Tutorial.
# [00:08.400 --> 00:13.400]  Ihr wartet schon sehr lange auf dieses Makeup Tutorial, endlich habe ich es gemacht, endlich habe ich es hochgeladen.
# [00:13.400 --> 00:20.400]  Ihr werdet heute das Makeup Tutorial zu diesem wunderschönen Look hier sehen und erfahren.
# [00:20.400 --> 00:25.800]  Und ich hoffe, ihr habt ganz viel Spaß, nicht erschrecken gleich, wenn der größte Catfish eures Lebens zu sehen ist.
# [00:25.800 --> 00:29.000]  Ich hoffe, ihr habt viel Spaß beim Video, wir sehen uns, let's go!
# [00:29.000 --> 00:35.000]  So, bevor wir mit irgendeinem Makeup anfangen oder sonst was, müssen wir diese Haare aus dem Gesicht bekommen.
# ...
